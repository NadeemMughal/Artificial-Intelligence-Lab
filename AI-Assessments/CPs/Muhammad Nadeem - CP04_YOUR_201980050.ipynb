# %% [markdown]
# # Class Partipation 04

# %% [markdown]
# ## Kindly follow the given instructions below
# 1. Download this file.
# 2. Rename your file with your ID like.,
#     - *YourName - CP04 - YOUR_ROLL_NUMBER* ==> $\color{blue}{\text{Muhammad Nadeem - CP04 - 201980050}}$
# 3. Write your solution of every question in its respective cell or block.
# 4. Upload this file with your solutions.
# 5. There will be **NO** any other file to be submitted.
# 6. Penalty for plagirisam is to be straight **ZERO**.
# 7. **NO LATE SUBMISSION.**
# 8. $\color{red}{\text{LATE SUBMISSION WILL BE MARKED ZERO}}$

# %% [markdown]
# ### 01. Employee Class
#
# Write a class named Employee that holds the following data about an employee in attributes:
# name, ID number, department, and job title.
#
# Once you have written the class, write a program that creates three Employee objects to
# hold the following data:
#
# |Name|ID|Number|Department|Job Title|
# |---|---|---|---|---|
# |Susan Meyers| 47899| |Accounting |Vice President
# |Mark Jones |39119| |IT| Programmer
# |Joy Rogers |81774| |Manufacturing| Engineer
#
# he program should store this data in the three objects and then display the data for each
# employee on the screen.

# %%
# write your code here.
class Employee:
    def __init__(self, name, ID, department, job_title):
        self.name = name
        self.ID = ID
        self.department = department
        self.job_title = job_title

employee1 = Employee("Muhammad Nadeem", 201980050, "Data Science", "Machine Learning Engineer")
employee2 = Employee("Sufyan Ahmad", 201980013, "Data Science", "Data Scientist")
employee3 = Employee("Wahab Khadim", 201980053, "Data Science", "Data Architect")

employees = [employee1, employee2, employee3]

for employee in employees:
    print("Name:", employee.name)
    print("ID Number:", employee.ID)
    print("Department:", employee.department)
    print("Job Title:", employee.job_title)
    print()
# Out:
# Name: Muhammad Nadeem
# ID Number: 201980050
# Department: Data Science
# Job Title: Machine Learning Engineer
#
# Name: Sufyan Ahmad
# ID Number: 201980013
# Department: Data Science
# Job Title: Data Scientist
#
# Name: Wahab Khadim
# ID Number: 201980053
# Department: Data Science
# Job Title: Data Architect

# %% [markdown]
# ### 02. Employee and ProductionWorker Classes
#
# Write an Employee class that keeps data attributes for the following pieces of information:
# * Employee name
# * Employee number
#
# Next, write a class named ProductionWorker that is a subclass of the Employee class. The
# ProductionWorker class should keep data attributes for the following information:
#
# * Shift number (an integer, such as 1, 2, or 3)
# * Hourly pay rate
#
# The workday is divided into two shifts: day and night. The shift attribute will hold an
# integer value representing the shift that the employee works. The day shift is shift 1 and the
# night shift is shift 2. Write the appropriate accessor and mutator methods for each class.
#
# Once you have written the classes, write a program that creates an object of the
# ProductionWorker class and prompts the user to enter data for each of the object’s data
# attributes. Store the data in the object and then use the object’s accessor methods to retrieve
# it and display it on the screen.

# %%
# write your code here.
class Employee:
    def __init__(self, name, number):
        self.__name = name
        self.__number = number

    def set_name(self, name):
        self.__name = name

    def set_number(self, number):
        self.__number = number

    def get_name(self):
        return self.__name

    def get_number(self):
        return self.__number

class ProductionWorker(Employee):
    def __init__(self, name, number, shift_number, hourly_pay_rate):
        Employee.__init__(self, name, number)
        self.__shift_number = shift_number
        self.__hourly_pay_rate = hourly_pay_rate

    def set_shift_number(self, shift_number):
        self.__shift_number = shift_number

    def set_hourly_pay_rate(self, hourly_pay_rate):
        self.__hourly_pay_rate = hourly_pay_rate

    def get_shift_number(self):
        return self.__shift_number

    def get_hourly_pay_rate(self):
        return self.__hourly_pay_rate

worker = ProductionWorker("", 0, 0, 0.0)

name = input("Enter the worker's name: ")
number = input("Enter the worker's number: ")
shift_number = int(input("Enter the worker's shift number (1 for day, 2 for night): "))
hourly_pay_rate = float(input("Enter the worker's hourly pay rate: "))

worker.set_name(name)
worker.set_number(number)
worker.set_shift_number(shift_number)
worker.set_hourly_pay_rate(hourly_pay_rate)

print("Worker's name:", worker.get_name())
print("Worker's number:", worker.get_number())
print("Worker's shift number:", worker.get_shift_number())
print("Worker's hourly pay rate:", worker.get_hourly_pay_rate())
# Out:
# Enter the worker's name: Nadeem
# Enter the worker's number: 0312-1428836
# Enter the worker's shift number (1 for day, 2 for night): 12
# Enter the worker's hourly pay rate: 2000
# Worker's name: Nadeem
# Worker's number: 0312-1428836
# Worker's shift number: 12
# Worker's hourly pay rate: 2000.0

# %% [markdown]
# ### 03. Person and Customer Classes
#
# Write a class named Person with data attributes for a person’s name, address, and telephone
# number. Next, write a class named Customer that is a subclass of the Person class.
# The Customer class should have a data attribute for a customer number and a Boolean
# data attribute indicating whether the customer wishes to be on a mailing list. Demonstrate
# an instance of the Customer class in a simple program.

# %%
# write your code here.
class Person:
    def __init__(self, name, address, telephone_number):
        self.__name = name
        self.__address = address
        self.__telephone_number = telephone_number

    def set_name(self, name):
        self.__name = name

    def set_address(self, address):
        self.__address = address

    def set_telephone_number(self, telephone_number):
        self.__telephone_number = telephone_number

    def get_name(self):
        return self.__name

    def get_address(self):
        return self.__address

    def get_telephone_number(self):
        return self.__telephone_number

class Customer(Person):
    def __init__(self, name, address, telephone_number, customer_number, mailing_list):
        Person.__init__(self, name, address, telephone_number)
        self.__customer_number = customer_number
        self.__mailing_list = mailing_list

    def set_customer_number(self, customer_number):
        self.__customer_number = customer_number

    def set_mailing_list(self, mailing_list):
        self.__mailing_list = mailing_list

    def get_customer_number(self):
        return self.__customer_number

    def get_mailing_list(self):
        return self.__mailing_list

customer = Customer("", "", "", 0, False)

name = input("Enter the customer's name: ")
address = input("Enter the customer's address: ")
telephone_number = input("Enter the customer's telephone number: ")
customer_number = int(input("Enter the customer's number: "))
mailing_list = input("Does the customer wish to be on the mailing list (True or False): ")

customer.set_name(name)
customer.set_address(address)
customer.set_telephone_number(telephone_number)
customer.set_customer_number(customer_number)
customer.set_mailing_list(mailing_list)

print("Customer's name:", customer.get_name())
print("Customer's address:", customer.get_address())
print("Customer's telephone number:", customer.get_telephone_number())
print("Customer's number:", customer.get_customer_number())
print("Customer's on mailing list:", customer.get_mailing_list())
# Out:
# Enter the customer's name: Nadeem
# Enter the customer's address: asb
# Enter the customer's telephone number: 03121428836
# Enter the customer's number: 37298729
# Does the customer wish to be on the mailing list (True or False): true
# Customer's name: Nadeem
# Customer's address: asb
# Customer's telephone number: 03121428836
# Customer's number: 37298729
# Customer's on mailing list: true
